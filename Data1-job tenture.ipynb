# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"G:/Sem_4/Milestone 1/14100050-eng/14100050.csv")

# %%
data
# Out:
#         REF_DATE               GEO           DGUID      Job tenure  \
# 0        1976-01            Canada  2016A000011124  Total employed
# 1        1976-01            Canada  2016A000011124  Total employed
# 2        1976-01            Canada  2016A000011124  Total employed
# 3        1976-01            Canada  2016A000011124  Total employed
# 4        1976-01            Canada  2016A000011124  Total employed
# ...          ...               ...             ...             ...
# 4338274  2021-01  British Columbia     2016A000259  Average tenure
# 4338275  2021-01  British Columbia     2016A000259  Average tenure
# 4338276  2021-01  British Columbia     2016A000259  Average tenure
# 4338277  2021-01  British Columbia     2016A000259  Average tenure
# 4338278  2021-01  British Columbia     2016A000259  Average tenure
#
#                                Type of work         Sex          Age group  \
# 0        Both full and part-time employment  Both sexes  15 years and over
# 1        Both full and part-time employment  Both sexes     15 to 24 years
# 2        Both full and part-time employment  Both sexes  25 years and over
# 3        Both full and part-time employment  Both sexes     25 to 44 years
# 4        Both full and part-time employment  Both sexes  45 years and over
# ...                                     ...         ...                ...
# 4338274                Part-time employment     Females  45 years and over
# 4338275                Part-time employment     Females     25 to 54 years
# 4338276                Part-time employment     Females  55 years and over
# 4338277                Part-time employment     Females     55 to 64 years
# 4338278                Part-time employment     Females  65 years and over
#
#              UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID    VECTOR  COORDINATE  \
# 0        Persons     249     thousands          3  v2824303   1.1.1.1.1
# 1        Persons     249     thousands          3  v2824330   1.1.1.1.2
# 2        Persons     249     thousands          3  v2824357   1.1.1.1.3
# 3        Persons     249     thousands          3  v2824411   1.1.1.1.4
# 4        Persons     249     thousands          3  v2824438   1.1.1.1.5
# ...          ...     ...           ...        ...       ...         ...
# 4338274   Months     220         units          0  v3180113  11.9.3.3.5
# 4338275   Months     220         units          0  v3180059  11.9.3.3.6
# 4338276   Months     220         units          0  v3180140  11.9.3.3.7
# 4338277   Months     220         units          0  v3180167  11.9.3.3.8
# 4338278   Months     220         units          0  v3180194  11.9.3.3.9
#
#           VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# 0        9271.4    NaN     NaN         NaN         1
# 1        2290.2    NaN     NaN         NaN         1
# 2        6981.2    NaN     NaN         NaN         1
# 3        4257.5    NaN     NaN         NaN         1
# 4        2723.7    NaN     NaN         NaN         1
# ...         ...    ...     ...         ...       ...
# 4338274   130.9    NaN     NaN         NaN         1
# 4338275    75.0    NaN     NaN         NaN         1
# 4338276   150.0    NaN     NaN         NaN         1
# 4338277   138.1    NaN     NaN         NaN         1
# 4338278   173.7    NaN     NaN         NaN         1
#
# [4338279 rows x 18 columns]

# %%
data.head()
# Out:
#   REF_DATE     GEO           DGUID      Job tenure  \
# 0  1976-01  Canada  2016A000011124  Total employed
# 1  1976-01  Canada  2016A000011124  Total employed
# 2  1976-01  Canada  2016A000011124  Total employed
# 3  1976-01  Canada  2016A000011124  Total employed
# 4  1976-01  Canada  2016A000011124  Total employed
#
#                          Type of work         Sex          Age group      UOM  \
# 0  Both full and part-time employment  Both sexes  15 years and over  Persons
# 1  Both full and part-time employment  Both sexes     15 to 24 years  Persons
# 2  Both full and part-time employment  Both sexes  25 years and over  Persons
# 3  Both full and part-time employment  Both sexes     25 to 44 years  Persons
# 4  Both full and part-time employment  Both sexes  45 years and over  Persons
#
#    UOM_ID SCALAR_FACTOR  SCALAR_ID    VECTOR COORDINATE   VALUE STATUS  \
# 0     249     thousands          3  v2824303  1.1.1.1.1  9271.4    NaN
# 1     249     thousands          3  v2824330  1.1.1.1.2  2290.2    NaN
# 2     249     thousands          3  v2824357  1.1.1.1.3  6981.2    NaN
# 3     249     thousands          3  v2824411  1.1.1.1.4  4257.5    NaN
# 4     249     thousands          3  v2824438  1.1.1.1.5  2723.7    NaN
#
#    SYMBOL  TERMINATED  DECIMALS
# 0     NaN         NaN         1
# 1     NaN         NaN         1
# 2     NaN         NaN         1
# 3     NaN         NaN         1
# 4     NaN         NaN         1

# %%
data.shape
# Out:
# (4338279, 18)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4338279, step=1)

# %%
data.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Job tenure', 'Type of work', 'Sex',
#        'Age group', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR',
#        'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
data.dtypes
# Out:
# REF_DATE          object
# GEO               object
# DGUID             object
# Job tenure        object
# Type of work      object
# Sex               object
# Age group         object
# UOM               object
# UOM_ID             int64
# SCALAR_FACTOR     object
# SCALAR_ID          int64
# VECTOR            object
# COORDINATE        object
# VALUE            float64
# STATUS            object
# SYMBOL           float64
# TERMINATED       float64
# DECIMALS           int64
# dtype: object

# %%
data.nunique()
# Out:
# REF_DATE           541
# GEO                 11
# DGUID               11
# Job tenure           9
# Type of work         3
# Sex                  3
# Age group            9
# UOM                  2
# UOM_ID               2
# SCALAR_FACTOR        3
# SCALAR_ID            2
# VECTOR            8019
# COORDINATE        8019
# VALUE            45387
# STATUS               1
# SYMBOL               0
# TERMINATED           0
# DECIMALS             1
# dtype: int64

# %%
data.count()
# Out:
# REF_DATE         4338279
# GEO              4338279
# DGUID            4338279
# Job tenure       4338279
# Type of work     4338279
# Sex              4338279
# Age group        4338279
# UOM              4338279
# UOM_ID           4338279
# SCALAR_FACTOR    4338279
# SCALAR_ID        4338279
# VECTOR           4338279
# COORDINATE       4338279
# VALUE            3791407
# STATUS            546872
# SYMBOL                 0
# TERMINATED             0
# DECIMALS         4338279
# dtype: int64

# %%
data['Age group'].unique
# Out:
# <bound method Series.unique of 0          15 years and over
# 1             15 to 24 years
# 2          25 years and over
# 3             25 to 44 years
# 4          45 years and over
#                  ...
# 4338274    45 years and over
# 4338275       25 to 54 years
# 4338276    55 years and over
# 4338277       55 to 64 years
# 4338278    65 years and over
# Name: Age group, Length: 4338279, dtype: object>

# %%
data['REF_DATE'].unique
# Out:
# <bound method Series.unique of 0          1976-01
# 1          1976-01
# 2          1976-01
# 3          1976-01
# 4          1976-01
#             ...
# 4338274    2021-01
# 4338275    2021-01
# 4338276    2021-01
# 4338277    2021-01
# 4338278    2021-01
# Name: REF_DATE, Length: 4338279, dtype: object>

# %%
data['GEO'].unique
# Out:
# <bound method Series.unique of 0                    Canada
# 1                    Canada
# 2                    Canada
# 3                    Canada
# 4                    Canada
#                  ...
# 4338274    British Columbia
# 4338275    British Columbia
# 4338276    British Columbia
# 4338277    British Columbia
# 4338278    British Columbia
# Name: GEO, Length: 4338279, dtype: object>

# %%
data['DGUID'].unique
# Out:
# <bound method Series.unique of 0          2016A000011124
# 1          2016A000011124
# 2          2016A000011124
# 3          2016A000011124
# 4          2016A000011124
#                 ...
# 4338274       2016A000259
# 4338275       2016A000259
# 4338276       2016A000259
# 4338277       2016A000259
# 4338278       2016A000259
# Name: DGUID, Length: 4338279, dtype: object>

# %%
data['Type of work'].unique
# Out:
# <bound method Series.unique of 0          Both full and part-time employment
# 1          Both full and part-time employment
# 2          Both full and part-time employment
# 3          Both full and part-time employment
# 4          Both full and part-time employment
#                           ...
# 4338274                  Part-time employment
# 4338275                  Part-time employment
# 4338276                  Part-time employment
# 4338277                  Part-time employment
# 4338278                  Part-time employment
# Name: Type of work, Length: 4338279, dtype: object>

# %%
data['Sex'].unique
# Out:
# <bound method Series.unique of 0          Both sexes
# 1          Both sexes
# 2          Both sexes
# 3          Both sexes
# 4          Both sexes
#               ...
# 4338274       Females
# 4338275       Females
# 4338276       Females
# 4338277       Females
# 4338278       Females
# Name: Sex, Length: 4338279, dtype: object>

# %%
data['UOM'].unique
# Out:
# <bound method Series.unique of 0          Persons
# 1          Persons
# 2          Persons
# 3          Persons
# 4          Persons
#             ...
# 4338274     Months
# 4338275     Months
# 4338276     Months
# 4338277     Months
# 4338278     Months
# Name: UOM, Length: 4338279, dtype: object>

# %%
data['Age group'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          15 years and over
# 1             15 to 24 years
# 2          25 years and over
# 3             25 to 44 years
# 4          45 years and over
#                  ...
# 4338274    45 years and over
# 4338275       25 to 54 years
# 4338276    55 years and over
# 4338277       55 to 64 years
# 4338278    65 years and over
# Name: Age group, Length: 4338279, dtype: object>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4338279 entries, 0 to 4338278
# Data columns (total 18 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   REF_DATE       object
#  1   GEO            object
#  2   DGUID          object
#  3   Job tenure     object
#  4   Type of work   object
#  5   Sex            object
#  6   Age group      object
#  7   UOM            object
#  8   UOM_ID         int64
#  9   SCALAR_FACTOR  object
#  10  SCALAR_ID      int64
#  11  VECTOR         object
#  12  COORDINATE     object
#  13  VALUE          float64
#  14  STATUS         object
#  15  SYMBOL         float64
#  16  TERMINATED     float64
#  17  DECIMALS       int64
# dtypes: float64(3), int64(3), object(12)
# memory usage: 595.8+ MB

# %%
data.head(2)
# Out:
#   REF_DATE     GEO           DGUID      Job tenure  \
# 0  1976-01  Canada  2016A000011124  Total employed
# 1  1976-01  Canada  2016A000011124  Total employed
#
#                          Type of work         Sex          Age group      UOM  \
# 0  Both full and part-time employment  Both sexes  15 years and over  Persons
# 1  Both full and part-time employment  Both sexes     15 to 24 years  Persons
#
#    UOM_ID SCALAR_FACTOR  SCALAR_ID    VECTOR COORDINATE   VALUE STATUS  \
# 0     249     thousands          3  v2824303  1.1.1.1.1  9271.4    NaN
# 1     249     thousands          3  v2824330  1.1.1.1.2  2290.2    NaN
#
#    SYMBOL  TERMINATED  DECIMALS
# 0     NaN         NaN         1
# 1     NaN         NaN         1

# %%
data['DGUID'].nunique()
# Out:
# 11

# %%
data['DGUID'].unique()
# Out:
# array(['2016A000011124', '2016A000210', '2016A000211', '2016A000212',
#        '2016A000213', '2016A000224', '2016A000235', '2016A000246',
#        '2016A000247', '2016A000248', '2016A000259'], dtype=object)

# %%
data['Age group'].nunique()
# Out:
# 9

# %%
data['Age group'].unique()
# Out:
# array(['15 years and over', '15 to 24 years', '25 years and over',
#        '25 to 44 years', '45 years and over', '25 to 54 years',
#        '55 years and over', '55 to 64 years', '65 years and over'],
#       dtype=object)

# %%
#value_counts()
data.DGUID.value_counts()
# Out:
# 2016A000210       394389
# 2016A000224       394389
# 2016A000246       394389
# 2016A000011124    394389
# 2016A000247       394389
# 2016A000235       394389
# 2016A000213       394389
# 2016A000211       394389
# 2016A000212       394389
# 2016A000248       394389
# 2016A000259       394389
# Name: DGUID, dtype: int64

# %%
#value_counts()
data.Sex.value_counts()
# Out:
# Females       1446093
# Males         1446093
# Both sexes    1446093
# Name: Sex, dtype: int64

# %%
#value_counts()
data.SCALAR_ID.value_counts()
# Out:
# 3    3856248
# 0     482031
# Name: SCALAR_ID, dtype: int64

# %%
#value_counts()
data.VECTOR.value_counts()
# Out:
# v3178609    541
# v3178723    541
# v2825800    541
# v3063908    541
# v2828027    541
#            ...
# v2827602    541
# v3063447    541
# v2824512    541
# v2826835    541
# v2825217    541
# Name: VECTOR, Length: 8019, dtype: int64

# %%
#value_counts()
data.VALUE.value_counts()
# Out:
# 0.5       47468
# 0.6       42746
# 0.7       38306
# 0.8       34697
# 0.9       32089
#           ...
# 3841.5        1
# 3846.0        1
# 3846.5        1
# 3847.5        1
# 1760.0        1
# Name: VALUE, Length: 45387, dtype: int64

# %%
data.head(2)
# Out:
#   REF_DATE     GEO           DGUID      Job tenure  \
# 0  1976-01  Canada  2016A000011124  Total employed
# 1  1976-01  Canada  2016A000011124  Total employed
#
#                          Type of work         Sex          Age group      UOM  \
# 0  Both full and part-time employment  Both sexes  15 years and over  Persons
# 1  Both full and part-time employment  Both sexes     15 to 24 years  Persons
#
#    UOM_ID SCALAR_FACTOR  SCALAR_ID    VECTOR COORDINATE   VALUE STATUS  \
# 0     249     thousands          3  v2824303  1.1.1.1.1  9271.4    NaN
# 1     249     thousands          3  v2824330  1.1.1.1.2  2290.2    NaN
#
#    SYMBOL  TERMINATED  DECIMALS
# 0     NaN         NaN         1
# 1     NaN         NaN         1

# %%
data[data['Sex'] == 'Both sexes']
# Out:
#         REF_DATE               GEO           DGUID      Job tenure  \
# 0        1976-01            Canada  2016A000011124  Total employed
# 1        1976-01            Canada  2016A000011124  Total employed
# 2        1976-01            Canada  2016A000011124  Total employed
# 3        1976-01            Canada  2016A000011124  Total employed
# 4        1976-01            Canada  2016A000011124  Total employed
# ...          ...               ...             ...             ...
# 4338256  2021-01  British Columbia     2016A000259  Average tenure
# 4338257  2021-01  British Columbia     2016A000259  Average tenure
# 4338258  2021-01  British Columbia     2016A000259  Average tenure
# 4338259  2021-01  British Columbia     2016A000259  Average tenure
# 4338260  2021-01  British Columbia     2016A000259  Average tenure
#
#                                Type of work         Sex          Age group  \
# 0        Both full and part-time employment  Both sexes  15 years and over
# 1        Both full and part-time employment  Both sexes     15 to 24 years
# 2        Both full and part-time employment  Both sexes  25 years and over
# 3        Both full and part-time employment  Both sexes     25 to 44 years
# 4        Both full and part-time employment  Both sexes  45 years and over
# ...                                     ...         ...                ...
# 4338256                Part-time employment  Both sexes  45 years and over
# 4338257                Part-time employment  Both sexes     25 to 54 years
# 4338258                Part-time employment  Both sexes  55 years and over
# 4338259                Part-time employment  Both sexes     55 to 64 years
# 4338260                Part-time employment  Both sexes  65 years and over
#
#              UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID    VECTOR  COORDINATE  \
# 0        Persons     249     thousands          3  v2824303   1.1.1.1.1
# 1        Persons     249     thousands          3  v2824330   1.1.1.1.2
# 2        Persons     249     thousands          3  v2824357   1.1.1.1.3
# 3        Persons     249     thousands          3  v2824411   1.1.1.1.4
# 4        Persons     249     thousands          3  v2824438   1.1.1.1.5
# ...          ...     ...           ...        ...       ...         ...
# 4338256   Months     220         units          0  v3179627  11.9.3.1.5
# 4338257   Months     220         units          0  v3179573  11.9.3.1.6
# 4338258   Months     220         units          0  v3179654  11.9.3.1.7
# 4338259   Months     220         units          0  v3179681  11.9.3.1.8
# 4338260   Months     220         units          0  v3179708  11.9.3.1.9
#
#           VALUE STATUS  SYMBOL  TERMINATED  DECIMALS
# 0        9271.4    NaN     NaN         NaN         1
# 1        2290.2    NaN     NaN         NaN         1
# 2        6981.2    NaN     NaN         NaN         1
# 3        4257.5    NaN     NaN         NaN         1
# 4        2723.7    NaN     NaN         NaN         1
# ...         ...    ...     ...         ...       ...
# 4338256   137.8    NaN     NaN         NaN         1
# 4338257    68.0    NaN     NaN         NaN         1
# 4338258   161.5    NaN     NaN         NaN         1
# 4338259   137.3    NaN     NaN         NaN         1
# 4338260   201.1    NaN     NaN         NaN         1
#
# [1446093 rows x 18 columns]

# %%
#find out all the null values in data
data.isnull()
# Out:
#          REF_DATE    GEO  DGUID  Job tenure  Type of work    Sex  Age group  \
# 0           False  False  False       False         False  False      False
# 1           False  False  False       False         False  False      False
# 2           False  False  False       False         False  False      False
# 3           False  False  False       False         False  False      False
# 4           False  False  False       False         False  False      False
# ...           ...    ...    ...         ...           ...    ...        ...
# 4338274     False  False  False       False         False  False      False
# 4338275     False  False  False       False         False  False      False
# 4338276     False  False  False       False         False  False      False
# 4338277     False  False  False       False         False  False      False
# 4338278     False  False  False       False         False  False      False
#
#            UOM  UOM_ID  SCALAR_FACTOR  SCALAR_ID  VECTOR  COORDINATE  VALUE  \
# 0        False   False          False      False   False       False  False
# 1        False   False          False      False   False       False  False
# 2        False   False          False      False   False       False  False
# 3        False   False          False      False   False       False  False
# 4        False   False          False      False   False       False  False
# ...        ...     ...            ...        ...     ...         ...    ...
# 4338274  False   False          False      False   False       False  False
# 4338275  False   False          False      False   False       False  False
# 4338276  False   False          False      False   False       False  False
# 4338277  False   False          False      False   False       False  False
# 4338278  False   False          False      False   False       False  False
#
#          STATUS  SYMBOL  TERMINATED  DECIMALS
# 0          True    True        True     False
# 1          True    True        True     False
# 2          True    True        True     False
# 3          True    True        True     False
# 4          True    True        True     False
# ...         ...     ...         ...       ...
# 4338274    True    True        True     False
# 4338275    True    True        True     False
# 4338276    True    True        True     False
# 4338277    True    True        True     False
# 4338278    True    True        True     False
#
# [4338279 rows x 18 columns]

# %%
data.isnull().sum()
# Out:
# REF_DATE               0
# GEO                    0
# DGUID                  0
# Job tenure             0
# Type of work           0
# Sex                    0
# Age group              0
# UOM                    0
# UOM_ID                 0
# SCALAR_FACTOR          0
# SCALAR_ID              0
# VECTOR                 0
# COORDINATE             0
# VALUE             546872
# STATUS           3791407
# SYMBOL           4338279
# TERMINATED       4338279
# DECIMALS               0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# REF_DATE         4338279
# GEO              4338279
# DGUID            4338279
# Job tenure       4338279
# Type of work     4338279
# Sex              4338279
# Age group        4338279
# UOM              4338279
# UOM_ID           4338279
# SCALAR_FACTOR    4338279
# SCALAR_ID        4338279
# VECTOR           4338279
# COORDINATE       4338279
# VALUE            3791407
# STATUS            546872
# SYMBOL                 0
# TERMINATED             0
# DECIMALS         4338279
# dtype: int64

# %%
data.head(2)
# Out:
#   REF_DATE     GEO           DGUID      Job tenure  \
# 0  1976-01  Canada  2016A000011124  Total employed
# 1  1976-01  Canada  2016A000011124  Total employed
#
#                          Type of work         Sex          Age group      UOM  \
# 0  Both full and part-time employment  Both sexes  15 years and over  Persons
# 1  Both full and part-time employment  Both sexes     15 to 24 years  Persons
#
#    UOM_ID SCALAR_FACTOR  SCALAR_ID    VECTOR COORDINATE   VALUE STATUS  \
# 0     249     thousands          3  v2824303  1.1.1.1.1  9271.4    NaN
# 1     249     thousands          3  v2824330  1.1.1.1.2  2290.2    NaN
#
#    SYMBOL  TERMINATED  DECIMALS
# 0     NaN         NaN         1
# 1     NaN         NaN         1

# %%
data.rename(columns = {'REF_DATE' : 'DATE'} , inplace=True)
data.head()
# Out:
#       DATE     GEO           DGUID      Job tenure  \
# 0  1976-01  Canada  2016A000011124  Total employed
# 1  1976-01  Canada  2016A000011124  Total employed
# 2  1976-01  Canada  2016A000011124  Total employed
# 3  1976-01  Canada  2016A000011124  Total employed
# 4  1976-01  Canada  2016A000011124  Total employed
#
#                          Type of work         Sex          Age group      UOM  \
# 0  Both full and part-time employment  Both sexes  15 years and over  Persons
# 1  Both full and part-time employment  Both sexes     15 to 24 years  Persons
# 2  Both full and part-time employment  Both sexes  25 years and over  Persons
# 3  Both full and part-time employment  Both sexes     25 to 44 years  Persons
# 4  Both full and part-time employment  Both sexes  45 years and over  Persons
#
#    UOM_ID SCALAR_FACTOR  SCALAR_ID    VECTOR COORDINATE   VALUE STATUS  \
# 0     249     thousands          3  v2824303  1.1.1.1.1  9271.4    NaN
# 1     249     thousands          3  v2824330  1.1.1.1.2  2290.2    NaN
# 2     249     thousands          3  v2824357  1.1.1.1.3  6981.2    NaN
# 3     249     thousands          3  v2824411  1.1.1.1.4  4257.5    NaN
# 4     249     thousands          3  v2824438  1.1.1.1.5  2723.7    NaN
#
#    SYMBOL  TERMINATED  DECIMALS
# 0     NaN         NaN         1
# 1     NaN         NaN         1
# 2     NaN         NaN         1
# 3     NaN         NaN         1
# 4     NaN         NaN         1

# %%
data.UOM_ID.mean()
# Out:
# 245.77777777777777

# %%
data.UOM_ID.std()
# Out:
# 9.113821785993148

# %%
data['UOM_ID'].var()
# Out:
# 83.06174754684332

# %%
data['Age group'].value_counts()
# Out:
# 15 to 24 years       482031
# 55 years and over    482031
# 55 to 64 years       482031
# 45 years and over    482031
# 25 to 54 years       482031
# 25 years and over    482031
# 65 years and over    482031
# 25 to 44 years       482031
# 15 years and over    482031
# Name: Age group, dtype: int64

# %%
data[data["UOM_ID"] == 220]
# Out:
#             DATE               GEO           DGUID      Job tenure  \
# 648      1976-01            Canada  2016A000011124  Average tenure
# 649      1976-01            Canada  2016A000011124  Average tenure
# 650      1976-01            Canada  2016A000011124  Average tenure
# 651      1976-01            Canada  2016A000011124  Average tenure
# 652      1976-01            Canada  2016A000011124  Average tenure
# ...          ...               ...             ...             ...
# 4338274  2021-01  British Columbia     2016A000259  Average tenure
# 4338275  2021-01  British Columbia     2016A000259  Average tenure
# 4338276  2021-01  British Columbia     2016A000259  Average tenure
# 4338277  2021-01  British Columbia     2016A000259  Average tenure
# 4338278  2021-01  British Columbia     2016A000259  Average tenure
#
#                                Type of work         Sex          Age group  \
# 648      Both full and part-time employment  Both sexes  15 years and over
# 649      Both full and part-time employment  Both sexes     15 to 24 years
# 650      Both full and part-time employment  Both sexes  25 years and over
# 651      Both full and part-time employment  Both sexes     25 to 44 years
# 652      Both full and part-time employment  Both sexes  45 years and over
# ...                                     ...         ...                ...
# 4338274                Part-time employment     Females  45 years and over
# 4338275                Part-time employment     Females     25 to 54 years
# 4338276                Part-time employment     Females  55 years and over
# 4338277                Part-time employment     Females     55 to 64 years
# 4338278                Part-time employment     Females  65 years and over
#
#             UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID    VECTOR  COORDINATE  VALUE  \
# 648      Months     220        units           0  v2824311   1.9.1.1.1   88.1
# 649      Months     220        units           0  v2824338   1.9.1.1.2   23.0
# 650      Months     220        units           0  v2824365   1.9.1.1.3  109.5
# 651      Months     220        units           0  v2824419   1.9.1.1.4   71.7
# 652      Months     220        units           0  v2824446   1.9.1.1.5  168.5
# ...         ...     ...           ...        ...       ...         ...    ...
# 4338274  Months     220         units          0  v3180113  11.9.3.3.5  130.9
# 4338275  Months     220         units          0  v3180059  11.9.3.3.6   75.0
# 4338276  Months     220         units          0  v3180140  11.9.3.3.7  150.0
# 4338277  Months     220         units          0  v3180167  11.9.3.3.8  138.1
# 4338278  Months     220         units          0  v3180194  11.9.3.3.9  173.7
#
#         STATUS  SYMBOL  TERMINATED  DECIMALS
# 648        NaN     NaN         NaN         1
# 649        NaN     NaN         NaN         1
# 650        NaN     NaN         NaN         1
# 651        NaN     NaN         NaN         1
# 652        NaN     NaN         NaN         1
# ...        ...     ...         ...       ...
# 4338274    NaN     NaN         NaN         1
# 4338275    NaN     NaN         NaN         1
# 4338276    NaN     NaN         NaN         1
# 4338277    NaN     NaN         NaN         1
# 4338278    NaN     NaN         NaN         1
#
# [482031 rows x 18 columns]

# %%
data.head(5)
# Out:
#       DATE     GEO           DGUID      Job tenure  \
# 0  1976-01  Canada  2016A000011124  Total employed
# 1  1976-01  Canada  2016A000011124  Total employed
# 2  1976-01  Canada  2016A000011124  Total employed
# 3  1976-01  Canada  2016A000011124  Total employed
# 4  1976-01  Canada  2016A000011124  Total employed
#
#                          Type of work         Sex          Age group      UOM  \
# 0  Both full and part-time employment  Both sexes  15 years and over  Persons
# 1  Both full and part-time employment  Both sexes     15 to 24 years  Persons
# 2  Both full and part-time employment  Both sexes  25 years and over  Persons
# 3  Both full and part-time employment  Both sexes     25 to 44 years  Persons
# 4  Both full and part-time employment  Both sexes  45 years and over  Persons
#
#    UOM_ID SCALAR_FACTOR  SCALAR_ID    VECTOR COORDINATE   VALUE STATUS  \
# 0     249     thousands          3  v2824303  1.1.1.1.1  9271.4    NaN
# 1     249     thousands          3  v2824330  1.1.1.1.2  2290.2    NaN
# 2     249     thousands          3  v2824357  1.1.1.1.3  6981.2    NaN
# 3     249     thousands          3  v2824411  1.1.1.1.4  4257.5    NaN
# 4     249     thousands          3  v2824438  1.1.1.1.5  2723.7    NaN
#
#    SYMBOL  TERMINATED  DECIMALS
# 0     NaN         NaN         1
# 1     NaN         NaN         1
# 2     NaN         NaN         1
# 3     NaN         NaN         1
# 4     NaN         NaN         1

# %%
data['VECTOR'].value_counts()[0:5]
# Out:
# v3178609    541
# v3178723    541
# v2825800    541
# v3063908    541
# v2828027    541
# Name: VECTOR, dtype: int64

# %%
plt.figure(figsize=(8, 5))
plt.bar(list(data['VECTOR'].value_counts()[0:5].keys()), list(data['VECTOR'].value_counts()[0:5]), color="g")
plt.show()

# %%
data['Age group'].value_counts()[0:5]
# Out:
# 15 to 24 years       482031
# 55 years and over    482031
# 55 to 64 years       482031
# 45 years and over    482031
# 25 to 54 years       482031
# Name: Age group, dtype: int64

# %%
plt.figure(figsize=(8, 5))
plt.bar(list(data['Age group'].value_counts()[0:5].keys()), list(data['Age group'].value_counts()[0:5]), color="b")
plt.show()

# %%
data['VALUE'].value_counts()
# Out:
# 0.5       47468
# 0.6       42746
# 0.7       38306
# 0.8       34697
# 0.9       32089
#           ...
# 3841.5        1
# 3846.0        1
# 3846.5        1
# 3847.5        1
# 1760.0        1
# Name: VALUE, Length: 45387, dtype: int64

# %%
plt.figure(figsize=(8, 5))
plt.bar(list(data['VALUE'].value_counts().keys()), list(data['VALUE'].value_counts()), color="g")
plt.show()

# %%
#making a pie chart
plt.figure(figsize=(7,10))
plt.pie(list(data['Age group'].value_counts()[0:500]), labels=list(data['Age group'].value_counts()[0:500].keys()),autopct='%0.1f%%')
plt.show()

# %%
#making a pie chart
plt.figure(figsize=(7,10))
plt.pie(list(data['Sex'].value_counts()), labels=list(data['Sex'].value_counts().keys()),autopct='%0.1f%%')
plt.show()

# %%
#making a pie chart
plt.figure(figsize=(7,10))
plt.pie(list(data['UOM_ID'].value_counts()), labels=list(data['UOM_ID'].value_counts().keys()),autopct='%0.1f%%')
plt.show()
